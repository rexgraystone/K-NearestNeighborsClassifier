# %% [markdown]
# # K-Nearest Neighbors classifier implementation using Library Classifier

# %%
from keras.datasets import mnist 
from sklearn.metrics import confusion_matrix as cm
from sklearn.neighbors import KNeighborsClassifier as kNN
from sklearn.utils import shuffle
from sklearn.metrics import classification_report as cr
import timeit as tt
import numpy as np
import pandas as pd
import random

# %% [markdown]
# Calculations and definitions of variables

# %%
k = 44 #Since our USNs end with 17 and 44, the 'k' value is 44
dp = 7100 #number of data points; (17 + 44) x 100 + 1000 = 7100
trp = 5680 #training points; 80% of 7100 = 5680
tp = 1420 #testing points; 20% of 7100 = 1420
n = 10 # Will be used for matrices and for-loops

# %% [markdown]
# Defining training and testing datas

# %%
(train_X, train_y), (test_X, test_y) = mnist.load_data()
train_X = train_X[:dp] # Resizing train_X with our required data points
train_X = np.reshape(train_X, (dp, 28*28)) 
train_y = train_y[:dp] # Resizing train_y with our required data points
test_X = test_X[:dp] # Resizing test_X with our required data points
test_X = np.reshape(test_X, (dp, 28*28))
test_y = test_y[:dp] # Resizing test_X with our required data points

# %% [markdown]
# Custom shuffle method for training data

# %%
# implementing mnist from keras in sklearn's train_test_split was complicated
def shufTrainData():
    X_shuf, y_shuf = shuffle(train_X, train_y)
    return (X_shuf, y_shuf)

# %% [markdown]
# Custom shuffle method for testing data

# %%
def shufTestData():
    X_shuf, y_shuf = shuffle(test_X, test_y)
    return (X_shuf, y_shuf)

# %% [markdown]
# Method to calculate the average runtime

# %%
def calcAvg(tAvg, total_1):
    if i == 0:
        tAvg = total_1
        return tAvg
    elif i != 0:
        tAvg = (tAvg + total_1)/(2)
        return tAvg

# %% [markdown]
# Cross Validation

# %%
cm_0 = np.zeros((n, n)) # Creating a temporary null matrix
# To calculate the sum of all the elements in the matrix
prec = 0

# To calculate total runtime for k iterations 
# Source: https://stackoverflow.com/questions/5622976/how-do-you-calculate-program-run-time-in-python
start_0 = tt.default_timer() 
t_avg = 0

for i in range(k):
    j = (i + 1)
    start_1 = tt.default_timer() # To calculate runtime  for each iteration
    print(f'Starting iteration - {i}') #To keep a track of how many iterations have finished
    knn = kNN(n_neighbors = k)
    X_train, y_train = shufTrainData()
    X_test, y_test = shufTestData()
    X_train = X_train[:trp]
    y_train = y_train[:trp]
    knn.fit(X_train, y_train)
    X_test = X_test[:tp]
    y_test = y_test[:tp]
    y_pred = knn.predict(X_test)
    cm_2 = cm(y_test, y_pred)
    cm_1 = cm_0 + cm_2
    cm_0 = cm_1
    prec += cm_0.diagonal()/cm_1.sum(axis = 0)
    print(f'Ending iteration - {i}')
    stop_1 = tt.default_timer() # To calculate runtime for each iteration
    total_1 = (stop_1 - start_1)
    t_avg = calcAvg(t_avg, total_1)
    print(f'Total runtime for iteration \'{i}\': {total_1} seconds.\n')
    
# To calculate total runtime for k iterations
stop_0 = tt.default_timer()
total_0 = (stop_0 - start_0) # Since time is stored in seconds and it is easier to read in minutes
for i in range(n):
    print(f'Precision of number {i} - {(prec[i]/k)*100} %')

cm_avg = cm_1/k # Creating a confusion matrix to store the average value
print(cm_avg)
print(f'Total runtime for {k} iterations: {total_0} seconds.') 
print(f'Average runtime per iteration: {t_avg} seconds.')
# Out:
# Starting iteration - 0
# Ending iteration - 0
# Total runtime for iteration '0': 0.23373991600237787 seconds.
#
# Starting iteration - 1
# Ending iteration - 1
# Total runtime for iteration '1': 0.21537570800137473 seconds.
#
# Starting iteration - 2
# Ending iteration - 2
# Total runtime for iteration '2': 0.2824932919975254 seconds.
#
# Starting iteration - 3
# Ending iteration - 3
# Total runtime for iteration '3': 0.2945945000028587 seconds.
#
# Starting iteration - 4
# Ending iteration - 4
# Total runtime for iteration '4': 0.1813179169985233 seconds.
#
# Starting iteration - 5
# Ending iteration - 5
# Total runtime for iteration '5': 0.20791841600293992 seconds.
#
# Starting iteration - 6
# Ending iteration - 6
# Total runtime for iteration '6': 0.21190950000163866 seconds.
#
# Starting iteration - 7
# Ending iteration - 7
# Total runtime for iteration '7': 0.199680083002022 seconds.
#
# Starting iteration - 8
# Ending iteration - 8
# Total runtime for iteration '8': 0.2043159589957213 seconds.
#
# Starting iteration - 9
# Ending iteration - 9
# Total runtime for iteration '9': 0.37471799999912037 seconds.
#
# Starting iteration - 10
# Ending iteration - 10
# Total runtime for iteration '10': 0.196239125005377 seconds.
#
# Starting iteration - 11
# Ending iteration - 11
# Total runtime for iteration '11': 0.24777562500094064 seconds.
#
# Starting iteration - 12
# Ending iteration - 12
# Total runtime for iteration '12': 0.23927316600020276 seconds.
#
# Starting iteration - 13
# Ending iteration - 13
# Total runtime for iteration '13': 0.2333324170031119 seconds.
#
# Starting iteration - 14
# Ending iteration - 14
# Total runtime for iteration '14': 0.18981966599676525 seconds.
#
# Starting iteration - 15
# Ending iteration - 15
# Total runtime for iteration '15': 0.19898062500578817 seconds.
#
# Starting iteration - 16
# Ending iteration - 16
# Total runtime for iteration '16': 0.1997549590014387 seconds.
#
# Starting iteration - 17
# Ending iteration - 17
# Total runtime for iteration '17': 0.31284799999411916 seconds.
#
# Starting iteration - 18
# Ending iteration - 18
# Total runtime for iteration '18': 0.2005324159981683 seconds.
#
# Starting iteration - 19
# Ending iteration - 19
# Total runtime for iteration '19': 0.20965266599523602 seconds.
#
# Starting iteration - 20
# Ending iteration - 20
# Total runtime for iteration '20': 0.20815633299935143 seconds.
#
# Starting iteration - 21
# Ending iteration - 21
# Total runtime for iteration '21': 0.2429005829981179 seconds.
#
# Starting iteration - 22
# Ending iteration - 22
# Total runtime for iteration '22': 0.23645766700064996 seconds.
#
# Starting iteration - 23
# Ending iteration - 23
# Total runtime for iteration '23': 0.20385458399687195 seconds.
#
# Starting iteration - 24
# Ending iteration - 24
# Total runtime for iteration '24': 0.3424786249961471 seconds.
#
# Starting iteration - 25
# Ending iteration - 25
# Total runtime for iteration '25': 0.2275430419977056 seconds.
#
# Starting iteration - 26
# Ending iteration - 26
# Total runtime for iteration '26': 0.21058991699828766 seconds.
#
# Starting iteration - 27
# Ending iteration - 27
# Total runtime for iteration '27': 0.21686462499928894 seconds.
#
# Starting iteration - 28
# Ending iteration - 28
# Total runtime for iteration '28': 0.19498925000516465 seconds.
#
# Starting iteration - 29
# Ending iteration - 29
# Total runtime for iteration '29': 0.267724208002619 seconds.
#
# Starting iteration - 30
# Ending iteration - 30
# Total runtime for iteration '30': 0.2010677919970476 seconds.
#
# Starting iteration - 31
# Ending iteration - 31
# Total runtime for iteration '31': 0.23303508399840211 seconds.
#
# Starting iteration - 32
# Ending iteration - 32
# Total runtime for iteration '32': 0.19869191600446356 seconds.
#
# Starting iteration - 33
# Ending iteration - 33
# Total runtime for iteration '33': 0.2454754589998629 seconds.
#
# Starting iteration - 34
# Ending iteration - 34
# Total runtime for iteration '34': 0.21662787500099512 seconds.
#
# Starting iteration - 35
# Ending iteration - 35
# Total runtime for iteration '35': 0.21581941699696472 seconds.
#
# Starting iteration - 36
# Ending iteration - 36
# Total runtime for iteration '36': 0.21464266599650728 seconds.
#
# Starting iteration - 37
# Ending iteration - 37
# Total runtime for iteration '37': 0.19996320900099818 seconds.
#
# Starting iteration - 38
# Ending iteration - 38
# Total runtime for iteration '38': 0.20636970800114796 seconds.
#
# Starting iteration - 39
# Ending iteration - 39
# Total runtime for iteration '39': 0.23521949999849312 seconds.
#
# Starting iteration - 40
# Ending iteration - 40
# Total runtime for iteration '40': 0.17690279200178338 seconds.
#
# Starting iteration - 41
# Ending iteration - 41
# Total runtime for iteration '41': 0.21667641599924536 seconds.
#
# Starting iteration - 42
# Ending iteration - 42
# Total runtime for iteration '42': 0.21921058299631113 seconds.
#
# Starting iteration - 43
# Ending iteration - 43
# Total runtime for iteration '43': 0.2349973329983186 seconds.
#
# Precision of number 0 - 92.52976126349425 %
# Precision of number 1 - 71.67519714074409 %
# Precision of number 2 - 98.26819223194197 %
# Precision of number 3 - 89.61062895179784 %
# Precision of number 4 - 91.53517495527336 %
# Precision of number 5 - 94.69249508350174 %
# Precision of number 6 - 93.24848790558018 %
# Precision of number 7 - 89.65497863181604 %
# Precision of number 8 - 95.47525367264018 %
# Precision of number 9 - 80.70873655669388 %
# [[1.31500000e+02 0.00000000e+00 0.00000000e+00 0.00000000e+00
#   9.09090909e-02 1.09090909e+00 1.81818182e+00 2.04545455e-01
#   2.04545455e-01 0.00000000e+00]
#  [0.00000000e+00 1.60977273e+02 3.18181818e-01 2.95454545e-01
#   0.00000000e+00 0.00000000e+00 2.27272727e-01 0.00000000e+00
#   0.00000000e+00 0.00000000e+00]
#  [1.95454545e+00 2.21363636e+01 1.09545455e+02 2.38636364e+00
#   7.50000000e-01 2.27272727e-02 1.56818182e+00 5.34090909e+00
#   2.43181818e+00 2.50000000e-01]
#  [6.81818182e-02 5.36363636e+00 5.68181818e-01 1.29954545e+02
#   1.81818182e-01 1.09090909e+00 5.90909091e-01 2.59090909e+00
#   1.50000000e+00 1.00000000e+00]
#  [1.13636364e-01 6.47727273e+00 0.00000000e+00 0.00000000e+00
#   1.21250000e+02 0.00000000e+00 1.86363636e+00 4.77272727e-01
#   2.27272727e-02 1.11136364e+01]
#  [9.54545455e-01 3.90909091e+00 4.54545455e-02 5.27272727e+00
#   1.59090909e+00 1.08840909e+02 2.61363636e+00 9.31818182e-01
#   6.59090909e-01 4.52272727e+00]
#  [2.09090909e+00 1.77272727e+00 2.27272727e-02 2.72727273e-01
#   2.86363636e+00 9.77272727e-01 1.26250000e+02 1.81818182e-01
#   0.00000000e+00 0.00000000e+00]
#  [0.00000000e+00 1.32954545e+01 0.00000000e+00 0.00000000e+00
#   8.86363636e-01 0.00000000e+00 0.00000000e+00 1.22090909e+02
#   0.00000000e+00 6.70454545e+00]
#  [3.79545455e+00 5.86363636e+00 4.54545455e-01 5.65909091e+00
#   2.40909091e+00 2.65909091e+00 9.54545455e-01 1.95454545e+00
#   1.08931818e+02 6.36363636e+00]
#  [2.09090909e+00 3.45454545e+00 1.81818182e-01 1.54545455e+00
#   2.86363636e+00 4.09090909e-01 2.27272727e-01 2.00000000e+00
#   1.13636364e-01 1.33977273e+02]]
# Total runtime for 44 iterations: 10.001122667003074 seconds.
# Average runtime per iteration: 0.22427481907377686 seconds.

# %% [markdown]
# Creating a Pandas Data Frame for better viewing of the result

# %%
df = pd.DataFrame(cm_avg)
df
# Out:
#             0           1           2           3           4           5  \
# 0  131.500000    0.000000    0.000000    0.000000    0.090909    1.090909
# 1    0.000000  160.977273    0.318182    0.295455    0.000000    0.000000
# 2    1.954545   22.136364  109.545455    2.386364    0.750000    0.022727
# 3    0.068182    5.363636    0.568182  129.954545    0.181818    1.090909
# 4    0.113636    6.477273    0.000000    0.000000  121.250000    0.000000
# 5    0.954545    3.909091    0.045455    5.272727    1.590909  108.840909
# 6    2.090909    1.772727    0.022727    0.272727    2.863636    0.977273
# 7    0.000000   13.295455    0.000000    0.000000    0.886364    0.000000
# 8    3.795455    5.863636    0.454545    5.659091    2.409091    2.659091
# 9    2.090909    3.454545    0.181818    1.545455    2.863636    0.409091
#
#             6           7           8           9
# 0    1.818182    0.204545    0.204545    0.000000
# 1    0.227273    0.000000    0.000000    0.000000
# 2    1.568182    5.340909    2.431818    0.250000
# 3    0.590909    2.590909    1.500000    1.000000
# 4    1.863636    0.477273    0.022727   11.113636
# 5    2.613636    0.931818    0.659091    4.522727
# 6  126.250000    0.181818    0.000000    0.000000
# 7    0.000000  122.090909    0.000000    6.704545
# 8    0.954545    1.954545  108.931818    6.363636
# 9    0.227273    2.000000    0.113636  133.977273

# %% [markdown]
# To calculate and verify the sum of all the elements in the matrix

# %%
s = 0
for i in range(n):
    for j in range(n):
        s += cm_avg[i][j]
        
s
# Out:
# 1420.0
